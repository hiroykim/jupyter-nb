# %%
from tika import parser

parsed = parser.from_file("C:\KMS_PROJECT\data\PPT2.pptx")
act =parsed['content']
act=act.strip().replace('\n',' ')
print(type(act))
print(act)
# Out:
# <class 'str'>
# ...

# %%
from tika import parser

parsed = parser.from_file("C:\jupyter_notebook\data\ppt1.pptx")
act =parsed['content']
act=act.strip().replace('\n',' ')
print(type(act))
print(act)
# Out:
# <class 'str'>
# 1번째 테스트입니다.  1번째 테스트입니다. 1번째 내용입니다.   2번째 테스트입니다. 2번째 내용입니다. 	1행1열	1행2열	1행3열 	2행1열	2행2열	3행3열    3번째 테스트입니다. 3번째 내용입니다.                                 /docProps/thumbnail.jpeg
