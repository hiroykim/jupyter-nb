# %%
from tika import parser

parsed = parser.from_file("C:\KMS_PROJECT\data\워드1.docx")
act =parsed['content']
act=act.strip().replace('\n',' ')
print(type(act))
print(act)
# Out:
# <class 'str'>
# ...

# %%
from tika import parser

parsed = parser.from_file("C:\KMS_PROJECT\data\한글1.hwp")
act =parsed['content']
act=act.strip().replace('\n',' ')
print(type(act))
print(act)
# Out:
# <class 'str'>
# ...

# %%
from tika import parser

parsed = parser.from_file("C:\KMS_PROJECT\data\한글2.hwp")
act =parsed['content']
act=act.strip().replace('\n',' ')
print(type(act))
print(act)
# Out:
# <class 'str'>
# ...
