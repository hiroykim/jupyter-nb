# %%
#pip install python-pptx
from pptx import Presentation
#ppt읽기
prs = Presentation("C:\KMS_PROJECT\data\PPT2.pptx")
result = []
for slide in prs.slides:
    for shape in slide.shapes:
        if not shape.has_text_frame:
            continue
        for paragraph in shape.text_frame.paragraphs:
            result.append(paragraph.text)
print(result)
# Out:
# ['영업지원 App. – 모바일 이미지시스템 오픈 안내 ', '2020.12 고객경험TF', '', '모바일 이미지시스템이란? ', '외부에서 급하게 서류를 스캔하거나 등록해야 할 때 많이 불편하셨죠?', ' ', '이런 불편함을 해소하기 위해, ', '핸드폰으로 이미지시스템에 문서를 등록할 수 있는 “모바일 이미지시스템＂을 오픈합니다.', '', '영업지원 App.  “이미지시스템“ 메뉴에서 사진 or 파일을 등록하시면, PC 이미지시스템에 문서가 바로 등록됩니다.', '자동차 블랙박스/마일리지 사진, 장기심사서류 등을 핸드폰으로 쉽고 편하게 등록해보세요!  ', '', '1', '영업지원 App. > 영업관리 클릭  ', '', '2', '이미지시스템 메뉴 클릭', '이미지시스템 클릭!', '모바일 이미지시스템은 영업지원 App.에서 이렇게 접속하시면 됩니다', '', '', '이미지시스템 메뉴를 클릭하시면, 3개의 화면(탭)으로 나눠집니다 ', '☞ 각 화면에 대한 설명은 다음 페이지로…', '자주 등록하는 문서', '이미지시스템 문서 등록', '이미지 등록 이력', 'FP님들이 이미지시스템에 가장 많이 등록하시는 문서를 ', '바로 등록할 수 있는 화면입니다.   ', '', '8개 문서를 여기서 바로 이미지시스템에 등록할 수 있습니다.', '', '① 자주 등록하는 문서 Tab', '고객', '           표시가 있다면! ', '고객에게 카카오 메시지를 보내 고객이 직접 서류를 등록할 수 있습니다 (카카오톡 미설치 고객은 문자로~) ', 'FP', '           표시가 있다면! ', 'FP님이 직접 핸드폰으로 사진을 찍거나, 핸드폰에 저장된 사진 을 업로드하거나, 핸드폰 파일을 등록할 수 있습니다. ', '(단, 신분증처럼 민감한 정보가 포함된 문서는 사진을 찍어 바로 업로드할 수만 있으며, 핸드폰에 사진 저장은 불가합니다) ', '', '① 자주 등록하는 문서 Tab', '', '', '[예시 1] 고객분께 카카오 메시지를 보내, 
# ...

# %%
from pptx import Presentation
prs = Presentation("C:\KMS_PROJECT\data\PPT2.pptx")

text_runs = []
for slide in prs.slides:
    for shape in slide.shapes:
        if not shape.has_table:
            continue    
        tbl = shape.table
        row_count = len(tbl.rows)
        col_count = len(tbl.columns)
        print(row_count, col_count)
        for r in range(0, row_count):
            for c in range(0, col_count):
                cell = tbl.cell(r,c)
                paragraphs = cell.text_frame.paragraphs
                for paragraph in paragraphs:
                    for run in paragraph.runs:
                        text_runs.append(run.text)

print(text_runs)
# Out:
# 28 7
# ...

# %%
import pandas as pd 
#sheetname = '시트명 or 숫자' , header = 숫자 skiprow=숫자 
xlsx = pd.read_excel('C:\KMS_PROJECT\data\엑셀1.xlsx') 
#상위 데이터 확인 
print(xlsx.head()) 
print() 
print(xlsx.tail()) 
print() 
print(xlsx.shape) 
#행, 열
# Out:
#       코드                  직업명  직업급수  \
# 0      1            관리자 (사무직)   NaN
# 1   1110  의회의원·고위공무원 및 공공단체임원   NaN
# 2  11101                 국회의원   1.0
# 3  11102        지방의회의원 및 교육위원   1.0
# 4  11103           중앙정부 고위공무원   1.0
#
#                                                 직업설명  \
# 0                                                NaN
# 1                                                NaN
# 2  국회를 주재하거나 그에 참여하고 법령을 제정, 비준, 개정 및 폐지하며 그들이 대표...
# 3  지방자치단체의 의회를 주재하거나 그에 참여하며, 헌법과 법령의 수권범위 내에서 조례...
# 4  정부의 정책을 결정하고 예산 및 법령안을 작성, 수정하며 정부 부처의 법령을 해석적...
#
#                                                 유사직업
# 0                                                NaN
# 1                                                NaN
# 2                                               국회의원
# 3          지방의회의원, 시의원, 도의원, 구의원, 군의원, 시군 및 자치구의회 의원
# 4  중앙정부고위공무원, 대통령, 대법원장, 헌법재판소장, 국무총리, 장관, 차관, 차관...
#
#          코드            직업명  직업급수                  직업설명             유사직업
# ...

# %%
import docx2txt
text = docx2txt.process('C:\KMS_PROJECT\data\워드1.docx')
print(text)
# Out:
# [갤러리 봄] 사용 설명서
#
#
#
#
#
#
#
# 창작마을 [상영관 봄]과 함께 [갤러리 봄]의 운영을 시작합니다.
#
#
#
# 학생들의 휴식 공간으로 활용되던 창작마을 2층 로비 공간이 갤러리 겸 문화 소통 공간으로 2020년 ‘리디자인’ 사업을 통해 완성되어 2020.11.2(월요일)을 시작으로 창작마을 [갤러리 봄]의 운영을 시작합니다.
#
#
#
# [갤러리 봄]은 전통적인 전시회와 함께, 다양한 행사들을 시도해 볼 수 있는 열린 공간입니다. 청강인 누구나 자유롭게 신청해서 다양성 있는 아이디어를 펼치는 공간입니다.
#
#
#
# 2020년 코로나 상황은 소통이 줄어들고 미래에 대한 불확실성에 청년들의 고민이 더 깊어지고 있습니다. [갤러리 봄]은 학생들이 창작자로서 다양한 시도를 시험하고, 소통하는 생기 넘치는 공간입니다.
#
#
#
# 전시장 신청 및 절차.
#
# - 전시 기간은 기본 30일 기준(전시 설치 / 철수 기간 포함)
#
# - 행사 기간은 자유롭게 신청 가능합니다.
#
# - 전시 설치 및 철수 날짜는 협의.
#
# (설치 당일 소음이 발생할 경우 수업이 없는 토요일에 설치 해야 함.)
#
# - 12월을 제외한 기간에 신청 가능하면 별도의 사용 비용은 없습니다.
#
#
#
# 대관 신청 절차.
#
# 일정 확인 후 전시 대관 신청서를 작성하여 offmanpj@ck.ac.kr 메일로 접수.
#
# 신청된 서류 검토 후 전시 작가와 전시회 관련 세부사항 논의 후 전시 확정.
#
# 자세한 내용은 애니메이션 스쿨 행정실 [031)639-4431~4]로 문의 부탁 드립니다.
#
#
#
# 신청자격
#
# 청강인 누구나 사용 가능합니다. 청강 문화 산업 대학교 교직원 및 학생 누구나 신청 가능.
#
# 신청 관련 자세한 내용은 애니메이션 스쿨 행정실에 문의해 주세요.
#
#
#
# 주의 사항
#
# ...

# %%
from urllib.request import urlopen
from pdfminer.pdfinterp import PDFResourceManager, process_pdf
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO
from io import open

def readPDF(pdfFile):
	rsrcmgr = PDFResourceManager()
	retstr = StringIO()
	laparams = LAParams()
	device = TextConverter(rsrcmgr, retstr, laparams=laparams)

	process_pdf(rsrcmgr, device, pdfFile)
	device.close()

	content = retstr.getvalue()
	retstr.close()

	return content

#pdfFile = urlopen("http://pythonscraping.com/pages/warandpeace/chapter1.pdf")
pdfFile = open('C:\KMS_PROJECT\data\PDF-2017년.pdf','rb')
outputString = readPDF(pdfFile)
print(outputString)
pdfFile.close()
# Out:
# 장기_상품약관_2017-0059
#
# 무배당 메리츠
#
# 케어프리보험 M-Basket1707
#
# 메 리 츠 화 재 해 상 보 험 주 식 회 사
#
# 개인신용정보 제공 ․ 이용에 대한
# 고객 권리 안내
#
# 1. 금융서비스 이용 범위
#    가. 고객의 개인신용정보는 금융거래의 설정 ․ 유지여부 판단 목적
# 및 고객이 동의한 목적만으로 이용됩니다.
#    나. 고객은 영업장 ․ 인터넷 등 다양한 채널을 통해 금융거래를 체
# 결하거나 금융서비스를 제공받는 과정에서 1) 금융회사가 본인
# 의  개인신용정보(이하 ‘본인정보’)를 제휴 ․ 부가서비스 등을
# 위해  제휴회사 등에 제공하는 것 및 2) 당해 금융회사가 금융
#
# 상품  소개 및 구매권유(이하 ‘마케팅’) 목적으로 이용하는
#
# 것에 대해 동의를 하지 않는 경우에도 금융거래를 체결하거나
# 금융서비스를 이용하실 수 있습니다. 다만, 이러한 동의를 하지
# 않으신   경우에는 제휴 ․ 부가서비스 및 신상품 ․ 서비스 등을
# 제공받지 못할 수도 있습니다.
# 2. ｢신용정보의 이용 및 보호에 관한 법률｣상의 고객 권리
#
#    가. 신용정보 이용 및 제공사실의 조회 요구
#
#       고객은 「신용정보의 이용 및 보호에 관한 법률」 제35조에
#
# 따라 금융회사가 본인정보를 마케팅 목적으로 이용·제공한 본
#
# 인정보의 주요 내용 등을 알려주도록 금융회사에 요구할 수 있
#
# 습니다.
#
#       - 신청방법
#
#         전화 : 1566-7711
#
#         홈페이지 : http://www.meritzfire.com
#
#    나. 금융거래 거절 근거 신용정보 고지 요구
#       고객은 ｢신용정보의 이용 및 보호에 관한 법률｣ 제36조에 따라
# 연체정보 등에 근거하여 금융거래를 거절 ․ 중지하는 경우에는
# 금융회사가 전국은행연합회, 신용조회회사 등으로부터 제공받은
# ...

# %%
import olefile
f = olefile.OleFileIO('C:\KMS_PROJECT\data\한글1.hwp')
encoded_text = f.openstream('PrvText').read()
decoded_text = encoded_text.decode('UTF-8')
print(decoded_text)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-3c7ff65c459f> in <module>
#       2 f = olefile.OleFileIO('C:\KMS_PROJECT\data\한글1.hwp')
#       3 encoded_text = f.openstream('PrvText').read()
# ----> 4 decoded_text = encoded_text.decode('UTF-8')
#       5 print(decoded_text)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa1 in position 0: invalid start byte

# %%
import sys
sys.version

# %%
import platform 
print(platform.architecture())
# Out:
# ('64bit', 'WindowsPE')

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
print(okt.pos('아버지가 방에 들어가신다'))
print(okt.pos('아버지가방에들어가신다'))

print(okt.pos('경기수원대리점'))
# Out:
# [('아버지', 'Noun'), ('가', 'Josa'), ('방', 'Noun'), ('에', 'Josa'), ('들어가신다', 'Verb')]
# [('아버지', 'Noun'), ('가방', 'Noun'), ('에', 'Josa'), ('들어가신다', 'Verb')]
# [('경기', 'Noun'), ('수원', 'Noun'), ('대리점', 'Noun')]

# %%
print(okt.pos('1번째 아해가 골목길을 달려간다.'))
print(okt.pos('2번째 아해가 골목길을 달려 간다.'))
# Out:
# [('1', 'Number'), ('번째', 'Suffix'), ('아해', 'Noun'), ('가', 'Josa'), ('골목길', 'Noun'), ('을', 'Josa'), ('달려간다', 'Verb'), ('.', 'Punctuation')]
# [('2', 'Number'), ('번째', 'Suffix'), ('아해', 'Noun'), ('가', 'Josa'), ('골목길', 'Noun'), ('을', 'Josa'), ('달려', 'Verb'), ('간다', 'Noun'), ('.', 'Punctuation')]
